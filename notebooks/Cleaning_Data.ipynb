# %%
kaggle datasets download -d user/dataset

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import json
import os 
import seaborn as sns

# %% [markdown]
# ## To download data

# %%
import json
import os

# %%
from kaggle.api.kaggle_api_extended import KaggleApi
api = KaggleApi()
api.authenticate()

# %%
 api.dataset_download_file('mrmorj/dataset-of-songs-in-spotify',
                          file_name='genres_v2.csv',
                          path='../')
# Out:
# False

# %%
url = has user and dataset

# %%
kaggle_credentials_path = os.path.expanduser("~/credentials/kaggle.json")
with open(kaggle_credentials_path) as f:
  kaggle_credentials = json.load(f)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-69-2f1b9d255006> in <module>
#       1 kaggle_credentials_path = os.path.expanduser("~/credentials/kaggle.json")
# ----> 2 with open(kaggle_credentials_path) as f:
#       3   kaggle_credentials = json.load(f)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/carlotaportillo/credentials/kaggle.json'

# %%
kaggle_credentials["username"]
# Out:
# 'carlotaswagarrigues'

# %%
download = "kaggle datasets download -d user/dataset-of-songs-in-spotify"

# %%
dataset = url.split("/")[-1]
user = url.split("/")[-2]

# %%
unzip = f'tar -xzvf ../genres_v2.csv.zip'
move_file = 'mv genres_v2.csv ..'
delete = f'rm -rf ../genres_v2.csv.zip'

# %%
os.system(unzip)
os.system(move_file)
os.system(delete)
# Out:
# 0

# %%
data = pd.read_csv('../genres_v2.csv')
# Out:
# /Users/carlotaportillo/Library/Python/3.9/lib/python/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
data.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence  ...                      id  \
# 0          0.013400    0.0556   0.3890  ...  2Vc6NJ9PW9gD9q343XFRKx
# 1          0.000000    0.1180   0.1240  ...  7pgJBLVz5VmnL7uGHmRj6p
# 2          0.000004    0.3720   0.0391  ...  0vSWgAlfpye0WCGeNmuNhy
# 3          0.000000    0.1140   0.1750  ...  0VSXnJqQkwuH2ei1nOQ1nu
# 4          0.000000    0.1660   0.5910  ...  4jCeguq9rMTlbMmPHuO7S3
#
#                                     uri  \
# 0  spotify:track:2Vc6NJ9PW9gD9q343XFRKx
# ...

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# title               21525
# Unnamed: 0          21525
# song_name           20786
# energy                  0
# genre                   0
# time_signature          0
# duration_ms             0
# analysis_url            0
# track_href              0
# uri                     0
# id                      0
# danceability            0
# tempo                   0
# valence                 0
# liveness                0
# instrumentalness        0
# acousticness            0
# speechiness             0
# mode                    0
# loudness                0
# key                     0
# type                    0
# dtype: int64

# %% [markdown]
#     Unos datos muy limpios. Excepto tres columnas que ademas su nombre ya indican que van a estar vacías. No solo buen/a programador/a sino tambien limpio/a. Nos desacemos de la que no nos sirven:

# %%
data.drop(['Unnamed: 0', 'time_signature', 'title', 'track_href', 'song_name', 'duration_ms','analysis_url', 'uri', 'id' ], axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['danceability', 'energy', 'key', 'loudness', 'mode', 'speechiness',
#        'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo',
#        'type', 'genre'],
#       dtype='object')

# %%
data.genre.value_counts()
# Out:
# Underground Rap    5875
# Dark Trap          4578
# Hiphop             3028
# trance             2999
# trap               2987
# techhouse          2975
# dnb                2966
# psytrance          2961
# techno             2956
# hardstyle          2936
# RnB                2099
# Trap Metal         1956
# Rap                1848
# Emo                1680
# Pop                 461
# Name: genre, dtype: int64

# %% [markdown]
# Ok. Pero por mucho que me guste el emo y pop, vamos a por los que tengan data robusta

# %%
counting_genres = data.genre.value_counts()

# %%
counting_genres[counting_genres>2900]
# Out:
# Underground Rap    5875
# Dark Trap          4578
# Hiphop             3028
# trance             2999
# trap               2987
# techhouse          2975
# dnb                2966
# psytrance          2961
# techno             2956
# hardstyle          2936
# Name: genre, dtype: int64

# %%
top_genres =  counting_genres[counting_genres>2900]

# %%
robust_data = data[data['genre'].isin(top_genres.index)]

# %%
robust_data.genre
# Out:
# 0        Dark Trap
# 1        Dark Trap
# 2        Dark Trap
# 3        Dark Trap
# 4        Dark Trap
#            ...
# 42300    hardstyle
# 42301    hardstyle
# 42302    hardstyle
# 42303    hardstyle
# 42304    hardstyle
# Name: genre, Length: 34261, dtype: object

# %%
robust_data.head()
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.831   0.814    2    -7.364     1       0.4200        0.0598
# 1         0.719   0.493    8    -7.230     1       0.0794        0.4010
# 2         0.850   0.893    5    -4.783     1       0.0623        0.0138
# 3         0.476   0.781    0    -4.710     1       0.1030        0.0237
# 4         0.798   0.624    2    -7.668     1       0.2930        0.2170
#
#    instrumentalness  liveness  valence    tempo            type      genre
# 0          0.013400    0.0556   0.3890  156.985  audio_features  Dark Trap
# 1          0.000000    0.1180   0.1240  115.080  audio_features  Dark Trap
# 2          0.000004    0.3720   0.0391  218.050  audio_features  Dark Trap
# 3          0.000000    0.1140   0.1750  186.948  audio_features  Dark Trap
# 4          0.000000    0.1660   0.5910  147.988  audio_features  Dark Trap

# %%
calambre = robust_data.filter(['danceability','tempo','energy', 'loudness','genre'], axis=1)

# %%
calambre.head()
# Out:
#    danceability    tempo  energy  loudness      genre
# 0         0.831  156.985   0.814    -7.364  Dark Trap
# 1         0.719  115.080   0.493    -7.230  Dark Trap
# 2         0.850  218.050   0.893    -4.783  Dark Trap
# 3         0.476  186.948   0.781    -4.710  Dark Trap
# 4         0.798  147.988   0.624    -7.668  Dark Trap

# %%
calambre['genre'] = calambre['genre'].str.lower()

# %%
calambre
# Out:
#        danceability    tempo  energy  loudness      genre
# 0             0.831  156.985   0.814    -7.364  dark trap
# 1             0.719  115.080   0.493    -7.230  dark trap
# 2             0.850  218.050   0.893    -4.783  dark trap
# 3             0.476  186.948   0.781    -4.710  dark trap
# 4             0.798  147.988   0.624    -7.668  dark trap
# ...             ...      ...     ...       ...        ...
# 42300         0.528  150.013   0.693    -5.148  hardstyle
# 42301         0.517  149.928   0.768    -7.922  hardstyle
# 42302         0.361  154.935   0.821    -3.102  hardstyle
# 42303         0.477  150.042   0.921    -4.777  hardstyle
# 42304         0.529  155.047   0.945    -5.862  hardstyle
#
# [34261 rows x 5 columns]

# %%
def maxi ():
    
    return max(_)

# %%
calambre.groupby('genre', sort=True)[['danceability','tempo','energy', 'loudness']].max()
# Out:
#                  danceability    tempo  energy  loudness
# genre
# dark trap               0.985  220.290   0.998     1.646
# dnb                     0.855  177.100   0.999     3.108
# hardstyle               0.774  157.687   0.999     0.101
# hiphop                  0.988  206.247   0.978    -0.067
# psytrance               0.925  157.033   0.999    -1.464
# techhouse               0.988  130.044   0.999    -1.318
# techno                  0.978  142.031   1.000    -1.927
# trance                  0.887  146.009   1.000    -1.093
# trap                    0.935  162.148   1.000     1.851
# underground rap         0.985  207.982   0.997     2.499

# %%
calambre.danceability.mean()
# Out:
# 0.637817171127521

# %%
calambre.danceability.median().round(2)
# Out:
# 0.64

# %%
calambre.groupby('genre')['danceability','tempo', 'energy', 'loudness'].mean().round(2)
# Out:
# <ipython-input-314-72ca22622adb>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   calambre.groupby('genre')['danceability','tempo', 'energy', 'loudness'].mean().round(2)
#                  danceability   tempo  energy  loudness
# genre
# dark trap                0.62  149.79    0.65     -8.00
# dnb                      0.52  173.85    0.87     -4.06
# hardstyle                0.48  150.66    0.90     -4.35
# hiphop                   0.70  162.98    0.65     -7.01
# psytrance                0.62  142.69    0.90     -6.70
# techhouse                0.79  124.93    0.83     -7.05
# techno                   0.72  128.97    0.80     -9.29
# trance                   0.51  134.63    0.89     -6.91
# trap                     0.59  147.69    0.91     -2.73
# underground rap          0.74  152.91    0.64     -7.36

# %%
mean = data.groupby('genre')['danceability', 'energy'].mean().round(2)
# Out:
# <ipython-input-127-85c3e3fa44d8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   mean = data.groupby('genre')['danceability', 'energy'].mean().round(2)

# %%
data.danceability.mean()
# Out:
# 0.6393643210022456

# %%
data.danceability.median().round(2)
# Out:
# 0.65

# %%
calambre.groupby('genre')['danceability'].mean().apply(lambda x: x> 0.65).sort_values()
# Out:
# genre
# dark trap          False
# dnb                False
# hardstyle          False
# psytrance          False
# trance             False
# trap               False
# hiphop              True
# techhouse           True
# techno              True
# underground rap     True
# Name: danceability, dtype: bool

# %%
data.energy.mean().round(2)
# Out:
# 0.76

# %%
data.energy.median().round(2)
# Out:
# 0.8

# %%
data.groupby('genre')['energy'].mean().apply(lambda x: x> 0.8).sort_values()
# Out:
# genre
# Dark Trap          False
# Emo                False
# Hiphop             False
# Pop                False
# Rap                False
# RnB                False
# Trap Metal         False
# Underground Rap    False
# techno             False
# dnb                 True
# hardstyle           True
# psytrance           True
# techhouse           True
# trance              True
# trap                True
# Name: energy, dtype: bool

# %%
[x['danceability'] for x in mean if x['danceability']>0.65]data.groupby('genre')['danceability'].mean().apply(lambda x: x> 0.65).sort_values()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-154-261556977d0b> in <module>
# ----> 1 [x['danceability'] for x in mean if x['danceability']>0.65]
#
# <ipython-input-154-261556977d0b> in <listcomp>(.0)
# ----> 1 [x['danceability'] for x in mean if x['danceability']>0.65]
#
# TypeError: string indices must be integers

# %%
url= "https://www.kaggle.com/mrmorj/dataset-of-songs-in-spotify"

# %% [markdown]
# Baileabilidad: describe como de bailable es un tema en funcion de su tempo, la estibilidad del ritmo y regularidad en general.

# %% [markdown]
# Energia: describe como de intenso y activo es el tema. Canciones con mucha energia son rapidas, fuertes y ruidosas.

# %%
url2 = "http://everynoise.com/countries.html"

# %%
response = requests.get(url2)

# %%
rank_genres = BeautifulSoup(response.content)

# %%
rank_genres
# Out:
# <html>
# <head>
# <meta charset="utf-8"/>
# <title>Genres by Country</title>
# <style>
# body, td {font: 14px "Gill Sans", "Gill Sans MT", "Trebuchet MS", sans-serif; background: white}
# .note {color: gray; padding: 12px 0px}
# .title {font-weight: bold; font-size: 200%; margin-right: 32px; margin-bottom: 16px}
# .title a {color: black}
# .genre {white-space: nowrap}
# .everything {padding-bottom: 12px}
# .country {padding-bottom: 6px}
# .section {border-left: 1px solid silver; padding-left: 16px}
# .count {padding-left: 6px; color: silver}
# .flag {padding-right: 2px}
# .nolist {color: gray}
#
# a {text-decoration: none; color: teal}
# a:hover {text-decoration: underline; color: red}
# td {white-space: nowrap}
# td.column {padding-right: 24px}
#
# </style>
# </head>
# <body>
# <div class="title"><a href="/engenremap.html">Every Noise at Once</a> · Genres by Country</div>
# <table border="0" cellpadding="0" cellspacing="0"><tr valign="top"><td style="padding-right: 64px">
# ...

# %%
os.getcwd()
# Out:
# '/Users/carlotaportillo/Desktop/Data lessons/using_Kaggle-API/notebooks'

# %%
csv.head
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-41802f5d7e19> in <module>
# ----> 1 csv.head
#
# AttributeError: 'str' object has no attribute 'head'
